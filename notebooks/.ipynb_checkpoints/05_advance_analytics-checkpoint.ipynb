# %%
## Historical VaR (95%) — 5th percentile of daily return distribution. CVaR = mean of returns below VaR threshold. Compute for all 40 schemes.

# %%
import pandas as pd
import numpy as np

# %%
nav = pd.read_csv("C:/MutualfundProject/data/raw/02_nav_history.csv")

nav.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
nav.columns
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='str')

# %%
nav['date'] = pd.to_datetime(nav['date'])

# %%
nav['date'].min(), nav['date'].max()
# Out:
# (Timestamp('2022-01-03 00:00:00'), Timestamp('2026-05-29 00:00:00'))

# %%
nav = nav.sort_values(['amfi_code', 'date'])

# %%
nav[nav['amfi_code'] == nav['amfi_code'].iloc[0]].head(10)
# Out:
#       amfi_code       date       nav
# 5750     100016 2022-01-03  520.4608
# 5751     100016 2022-01-04  515.0971
# 5752     100016 2022-01-05  521.7239
# 5753     100016 2022-01-06  515.7880
# 5754     100016 2022-01-07  515.1639
# 5755     100016 2022-01-10  510.7136
# 5756     100016 2022-01-11  513.5542
# 5757     100016 2022-01-12  512.3195
# 5758     100016 2022-01-13  510.2445
# 5759     100016 2022-01-14  514.3636

# %%
nav['daily_return'] = (
    nav.groupby('amfi_code')['nav']
       .pct_change()
)

# %%
nav.head(10)
# Out:
#       amfi_code       date       nav  daily_return
# 5750     100016 2022-01-03  520.4608           NaN
# 5751     100016 2022-01-04  515.0971     -0.010306
# 5752     100016 2022-01-05  521.7239      0.012865
# 5753     100016 2022-01-06  515.7880     -0.011377
# 5754     100016 2022-01-07  515.1639     -0.001210
# 5755     100016 2022-01-10  510.7136     -0.008639
# 5756     100016 2022-01-11  513.5542      0.005562
# 5757     100016 2022-01-12  512.3195     -0.002404
# 5758     100016 2022-01-13  510.2445     -0.004050
# 5759     100016 2022-01-14  514.3636      0.008073

# %%
returns = nav.dropna(subset=['daily_return']).copy()

# %%
returns['daily_return'].isna().sum()
# Out:
# np.int64(0)

# %%
returns['daily_return'].describe()
# Out:
# count    45960.000000
# mean         0.000631
# std          0.010290
# min         -0.058102
# 25%         -0.005042
# 50%          0.000340
# 75%          0.006324
# max          0.064713
# Name: daily_return, dtype: float64

# %%
returns.sort_values('daily_return').head(10)
# Out:
#        amfi_code       date       nav  daily_return
# 19674     118634 2022-06-24   67.2534     -0.058102
# 33667     101207 2023-03-22   56.8326     -0.051847
# 19852     118634 2023-03-01  113.5801     -0.050335
# 45312     149324 2023-10-11  111.8155     -0.048870
# 34310     101207 2025-09-08   62.3200     -0.048634
# 31304     119095 2022-12-23   73.9946     -0.048367
# 20233     118634 2024-08-15  114.5168     -0.048305
# 31807     119095 2024-11-27   78.1317     -0.046524
# 4198      119599 2024-11-14  112.8996     -0.045429
# 9770      125498 2024-03-11  131.4556     -0.045218

# %%
returns.sort_values('daily_return', ascending=False).head(10)
# Out:
#        amfi_code       date       nav  daily_return
# 2895      119598 2024-04-15  189.0742      0.064713
# 20126     118634 2024-03-19  110.5401      0.059304
# 33957     101207 2024-05-01   65.5882      0.054851
# 3716      119599 2023-01-10  153.2221      0.053320
# 3982      119599 2024-01-17  136.8239      0.051811
# 2305      119598 2022-01-10   96.0964      0.051113
# 2521      119598 2022-11-08  123.9704      0.049051
# 45082     149324 2022-11-23   98.3696      0.048490
# 2506      119598 2022-10-18  122.2757      0.048454
# 3241      119598 2025-08-12  200.8460      0.047123

# %%
var_95 = returns['daily_return'].quantile(0.05)

# %%
var_results = (
    returns.groupby('amfi_code')['daily_return']
           .quantile(0.05)
           .reset_index()
)

# %%
var_results = var_results.rename(
    columns={'daily_return': 'VaR_95'}
)

# %%
var_results.head()
# Out:
#    amfi_code    VaR_95
# 0     100016 -0.014364
# 1     100025 -0.003793
# 2     100033 -0.019034
# 3     101206 -0.013282
# 4     101207 -0.026021

# %%
def calculate_var_cvar(group):
    
    var = group['daily_return'].quantile(0.05)
    
    cvar = group.loc[
        group['daily_return'] <= var,
        'daily_return'
    ].mean()
    
    return pd.Series({
        'VaR_95': var,
        'CVaR_95': cvar
    })

# %%
risk_results = (
    returns
    .groupby('amfi_code')
    .apply(calculate_var_cvar)
    .reset_index()
)

# %%
risk_results.head(10)
# Out:
#    amfi_code    VaR_95   CVaR_95
# 0     100016 -0.014364 -0.018060
# 1     100025 -0.003793 -0.004994
# 2     100033 -0.019034 -0.023456
# 3     101206 -0.013282 -0.017439
# 4     101207 -0.026021 -0.032459
# 5     101208 -0.000269 -0.000422
# 6     102885 -0.012613 -0.015490
# 7     102886 -0.019220 -0.023251
# 8     102887 -0.015232 -0.019411
# 9     118632 -0.013954 -0.017619

# %%
risk_results['VaR_95_pct'] = risk_results['VaR_95'] * 100
risk_results['CVaR_95_pct'] = risk_results['CVaR_95'] * 100

# %%
risk_results['amfi_code'].nunique()
# Out:
# 40

# %%
returns['amfi_code'].nunique()
# Out:
# 40

# %%
all_schemes = set(nav['amfi_code'].unique())
risk_schemes = set(risk_results['amfi_code'].unique())

missing_schemes = all_schemes - risk_schemes

missing_schemes
# Out:
# set()

# %%
fund_master = pd.read_csv("C:/MutualFundProject/data/raw/01_fund_master.csv")

# %%
fund_master.columns
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='str')

# %%
risk_results = risk_results.merge(
    fund_master[['amfi_code', 'scheme_name', 'fund_house', 'category']],
    on='amfi_code',
    how='left'
)

# %%
risk_results.head()
# Out:
#    amfi_code    VaR_95   CVaR_95  VaR_95_pct  CVaR_95_pct  \
# 0     100016 -0.014364 -0.018060   -1.436364    -1.806021
# 1     100025 -0.003793 -0.004994   -0.379325    -0.499376
# 2     100033 -0.019034 -0.023456   -1.903354    -2.345576
# 3     101206 -0.013282 -0.017439   -1.328166    -1.743943
# 4     101207 -0.026021 -0.032459   -2.602125    -3.245906
#
#                                          scheme_name  \
# 0          HDFC Top 100 Fund - Regular Plan - Growth
# 1       HDFC Short Term Debt Fund - Regular - Growth
# 2  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 3      ABSL Frontline Equity Fund - Regular - Growth
# 4             ABSL Small Cap Fund - Regular - Growth
#
#                  fund_house category
# 0          HDFC Mutual Fund   Equity
# 1          HDFC Mutual Fund     Debt
# 2          HDFC Mutual Fund   Equity
# 3  Aditya Birla Sun Life MF   Equity
# 4  Aditya Birla Sun Life MF   Equity

# %%
risk_results.sort_values(
    'VaR_95_pct'
).head(10)
# Out:
#     amfi_code    VaR_95   CVaR_95  VaR_95_pct  CVaR_95_pct  \
# 22     119599 -0.026859 -0.032384   -2.685944    -3.238412
# 17     119095 -0.026188 -0.031667   -2.618842    -3.166729
# 4      101207 -0.026021 -0.032459   -2.602125    -3.245906
# 11     118634 -0.025438 -0.032304   -2.543811    -3.230407
# 21     119598 -0.024507 -0.030595   -2.450705    -3.059526
# 39     149324 -0.023483 -0.031036   -2.348307    -3.103625
# 7      102886 -0.019220 -0.023251   -1.922028    -2.325086
# 2      100033 -0.019034 -0.023456   -1.903354    -2.345576
# 25     120505 -0.018892 -0.024342   -1.889179    -2.434207
# 16     119094 -0.018480 -0.024260   -1.848028    -2.426006
#
#                                           scheme_name  \
# 22          SBI Small Cap Fund - Direct Plan - Growth
# 17             Axis Small Cap Fund - Regular - Growth
# 4              ABSL Small Cap Fund - Regular - Growth
# 11     Nippon India Small Cap Fund - Regular - Growth
# ...

# %%
final_risk_table = risk_results[
    [
        'amfi_code',
        'scheme_name',
        'fund_house',
        'category',
        'VaR_95_pct',
        'CVaR_95_pct'
    ]
].sort_values('VaR_95_pct')

# %%
final_risk_table
# Out:
#     amfi_code                                        scheme_name  \
# 22     119599          SBI Small Cap Fund - Direct Plan - Growth
# 17     119095             Axis Small Cap Fund - Regular - Growth
# 4      101207             ABSL Small Cap Fund - Regular - Growth
# 11     118634     Nippon India Small Cap Fund - Regular - Growth
# 21     119598         SBI Small Cap Fund - Regular Plan - Growth
# 39     149324              DSP Small Cap Fund - Regular - Growth
# 7      102886                UTI Mid Cap Fund - Regular - Growth
# 2      100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 25     120505           ICICI Pru Midcap Fund - Regular - Growth
# 16     119094                Axis Midcap Fund - Regular - Growth
# 33     125498  HDFC Mid-Cap Opportunities Fund - Direct - Growth
# 29     120842      Kotak Emerging Equity Fund - Regular - Growth
# 38     149323                 DSP Midcap Fund - Regular - Growth
# ...

# %%
final_risk_table['VaR_95_pct'] = (
    final_risk_table['VaR_95_pct'].round(2)
)

final_risk_table['CVaR_95_pct'] = (
    final_risk_table['CVaR_95_pct'].round(2)
)

# %%
final_risk_table.to_csv(
    "C:/MutualFundProject/data/processed/Advanced_Analytics_CSV_file/01_historical_var_cvar_40_schemes.csv",
    index=False
)

# %%
## Rolling 90-day Sharpe — returns.rolling(90).mean() / returns.rolling(90).std() × √252. Plot over time for 5 key funds.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

nav = pd.read_csv("C:/MutualFundProject/data/raw/02_nav_history.csv")

nav.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
nav.columns
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='str')

# %%
nav['date'] = pd.to_datetime(nav['date'])

# %%
nav = nav.sort_values(['amfi_code', 'date'])

# %%
nav['daily_return'] = (
    nav.groupby('amfi_code')['nav']
       .pct_change()
)

# %%
nav[['amfi_code', 'date', 'nav', 'daily_return']].head(10)
# Out:
#       amfi_code       date       nav  daily_return
# 5750     100016 2022-01-03  520.4608           NaN
# 5751     100016 2022-01-04  515.0971     -0.010306
# 5752     100016 2022-01-05  521.7239      0.012865
# 5753     100016 2022-01-06  515.7880     -0.011377
# 5754     100016 2022-01-07  515.1639     -0.001210
# 5755     100016 2022-01-10  510.7136     -0.008639
# 5756     100016 2022-01-11  513.5542      0.005562
# 5757     100016 2022-01-12  512.3195     -0.002404
# 5758     100016 2022-01-13  510.2445     -0.004050
# 5759     100016 2022-01-14  514.3636      0.008073

# %%
returns = nav.dropna(subset = ['daily_return']).copy()

# %%
returns['rolling_mean_90'] = (
    returns.groupby('amfi_code')['daily_return']
           .transform(lambda x: x.rolling(90).mean())
)

returns['rolling_std_90'] = (
    returns.groupby('amfi_code')['daily_return']
           .transform(lambda x: x.rolling(90).std())
)

# %%
returns['rolling_sharpe_90'] = (
    returns['rolling_mean_90']
    / returns['rolling_std_90']
    * np.sqrt(252)
)

# %%
returns[
    returns['amfi_code'] == returns['amfi_code'].iloc[0]
][['date', 'daily_return', 'rolling_sharpe_90']].head(95)
# Out:
#            date  daily_return  rolling_sharpe_90
# 5751 2022-01-04     -0.010306                NaN
# 5752 2022-01-05      0.012865                NaN
# 5753 2022-01-06     -0.011377                NaN
# 5754 2022-01-07     -0.001210                NaN
# 5755 2022-01-10     -0.008639                NaN
# ...         ...           ...                ...
# 5841 2022-05-10     -0.009987          -0.058880
# 5842 2022-05-11     -0.012576          -0.532521
# 5843 2022-05-12     -0.018051          -0.649005
# 5844 2022-05-13      0.006898          -0.498278
# 5845 2022-05-16     -0.004283          -0.419782
#
# [95 rows x 3 columns]

# %%
key_funds = [
    119551,  # SBI Bluechip
    120503,  # ICICI Bluechip
    118632,  # Nippon Large Cap
    119092,  # Axis Bluechip
    120841   # Kotak Bluechip
]

# %%
rolling_sharpe_5 = returns[
    returns['amfi_code'].isin(key_funds)
].copy()

# %%
rolling_sharpe_5['amfi_code'].nunique()
# Out:
# 5

# %%
fund_master = pd.read_csv("C:/Mutualfundproject/data/raw/01_fund_master.csv")

fund_master.columns
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='str')

# %%
rolling_sharpe_5 = rolling_sharpe_5.merge(
    fund_master[['amfi_code', 'scheme_name']],
    on='amfi_code',
    how='left'
)

# %%
rolling_sharpe_5[
    ['date', 'amfi_code', 'scheme_name', 'rolling_sharpe_90']
].head()
# Out:
#         date  amfi_code                                     scheme_name  \
# 0 2022-01-04     118632  Nippon India Large Cap Fund - Regular - Growth
# 1 2022-01-05     118632  Nippon India Large Cap Fund - Regular - Growth
# 2 2022-01-06     118632  Nippon India Large Cap Fund - Regular - Growth
# 3 2022-01-07     118632  Nippon India Large Cap Fund - Regular - Growth
# 4 2022-01-10     118632  Nippon India Large Cap Fund - Regular - Growth
#
#    rolling_sharpe_90
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
plt.figure(figsize=(16, 8))

sns.lineplot(
    data=rolling_sharpe_5,
    x='date',
    y='rolling_sharpe_90',
    hue='scheme_name'
)

plt.axhline(
    0,
    linestyle='--',
    linewidth=1
)

plt.title('90-Day Rolling Sharpe Ratio — 5 Key Funds')
plt.xlabel('Date')
plt.ylabel('Rolling Sharpe Ratio')
plt.legend(title='Fund')
plt.tight_layout()

plt.show()

# %%
fund_summary = (
    rolling_sharpe_5
    .groupby('scheme_name')['rolling_sharpe_90']
    .agg(
        average_rolling_sharpe='mean',
        maximum_rolling_sharpe='max',
        minimum_rolling_sharpe='min'
    )
    .reset_index()
)

# %%
fund_summary.sort_values(
    'average_rolling_sharpe',
    ascending=False
)
# Out:
#                                       scheme_name  average_rolling_sharpe  \
# 4       SBI Bluechip Fund - Regular Plan - Growth                1.727788
# 3  Nippon India Large Cap Fund - Regular - Growth                1.402335
# 1      ICICI Pru Bluechip Fund - Regular - Growth                1.040287
# 2          Kotak Bluechip Fund - Regular - Growth                0.971429
# 0           Axis Bluechip Fund - Regular - Growth                0.617369
#
#    maximum_rolling_sharpe  minimum_rolling_sharpe
# 4                6.446039               -2.465994
# 3                5.265426               -3.267884
# 1                5.010124               -3.299569
# 2                6.769155               -3.639571
# 0                4.766055               -2.416716

# %%
plt.figure(figsize=(16, 8))

sns.lineplot(
    data=rolling_sharpe_5,
    x='date',
    y='rolling_sharpe_90',
    hue='scheme_name'
)

plt.axhline(
    0,
    linestyle='--',
    linewidth=1
)

plt.title('90-Day Rolling Sharpe Ratio — 5 Key Funds')
plt.xlabel('Date')
plt.ylabel('Rolling Sharpe Ratio')
plt.legend(title='Fund')
plt.tight_layout()

plt.savefig(
    "C:/MutualFundProject/data/processed/Advanced_Analytics_CSV_file/reports/rolling_90_day_sharpe_5_funds.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
returns.rolling(90)
# Out:
# Rolling [window=90,center=False,method=single]

# %%
returns.groupby('amfi_code')

# %%
## Investor cohort analysis — group by first transaction year. Compute avg SIP amount, total invested, and top fund preference per cohort.

# %%
import pandas as pd
import numpy as np

transactions = pd.read_csv(
    "C:/MutualFundproject/data/raw/08_investor_transactions.csv"
)

transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
transactions.columns
# Out:
# Index(['investor_id', 'transaction_date', 'amfi_code', 'transaction_type',
#        'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender',
#        'annual_income_lakh', 'payment_mode', 'kyc_status'],
#       dtype='str')

# %%
transactions.shape
transactions.dtypes
# Out:
# investor_id               str
# transaction_date          str
# amfi_code               int64
# transaction_type          str
# amount_inr              int64
# state                     str
# city                      str
# city_tier                 str
# age_group                 str
# gender                    str
# annual_income_lakh    float64
# payment_mode              str
# kyc_status                str
# dtype: object

# %%
transactions['transaction_date'] = pd.to_datetime(
    transactions['transaction_date']
)

# %%
transactions['transaction_date'].min()
transactions['transaction_date'].max()
# Out:
# Timestamp('2025-05-30 00:00:00')

# %%
first_transaction = (
    transactions
    .groupby('investor_id')['transaction_date']
    .min()
    .reset_index()
)

# %%
first_transaction = first_transaction.rename(
    columns={
        'transaction_date': 'first_transaction_date'
    }
)

# %%
first_transaction.head()
# Out:
#   investor_id first_transaction_date
# 0   INV000001             2024-11-04
# 1   INV000002             2024-03-29
# 2   INV000003             2024-07-16
# 3   INV000004             2024-03-16
# 4   INV000005             2024-04-27

# %%
first_transaction['cohort_year'] = (
    first_transaction['first_transaction_date']
    .dt.year
)

# %%
transactions = transactions.merge(
    first_transaction[
        ['investor_id', 'cohort_year']
    ],
    on='investor_id',
    how='left'
)

# %%
transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status  cohort_year
# 0          UPI   Verified         2024
# ...

# %%
sip_transactions = transactions[
    transactions['transaction_type'].str.upper() == 'SIP'
].copy()

# %%
avg_sip = (
    sip_transactions
    .groupby('cohort_year')['amount_inr']
    .mean()
    .reset_index()
)

# %%
avg_sip = avg_sip.rename(
    columns={
        'amount_inr': 'avg_sip_amount'
    }
)

# %%
avg_sip
# Out:
#    cohort_year  avg_sip_amount
# 0         2024    10996.885825
# 1         2025    13505.209581

# %%
investment_transactions = transactions[
    transactions['transaction_type'].str.upper().isin(
        ['SIP', 'LUMPSUM']
    )
].copy()

# %%
total_invested = (
    investment_transactions
    .groupby('cohort_year')['amount_inr']
    .sum()
    .reset_index()
)

# %%
total_invested = total_invested.rename(
    columns={
        'amount_inr': 'total_invested'
    }
)

# %%
fund_preference = (
    transactions
    .groupby(['cohort_year', 'amfi_code'])
    .size()
    .reset_index(name='transaction_count')
)

# %%
fund_preference.head()
# Out:
#    cohort_year  amfi_code  transaction_count
# 0         2024     100016                830
# 1         2024     100025                791
# 2         2024     100033                781
# 3         2024     101206                803
# 4         2024     101207                844

# %%
fund_preference = fund_preference.sort_values(
    ['cohort_year', 'transaction_count'],
    ascending=[True, False]
)

# %%
top_fund = (
    fund_preference
    .groupby('cohort_year')
    .first()
    .reset_index()
)

# %%
top_fund
# Out:
#    cohort_year  amfi_code  transaction_count
# 0         2024     148568                874
# 1         2025     119599                 12

# %%
fund_master = pd.read_csv(
    "C:/MutualFundProject/data/raw/01_fund_master.csv"
)

# %%
fund_master.columns
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='str')

# %%
top_fund = top_fund.merge(
    fund_master[['amfi_code', 'scheme_name']],
    on='amfi_code',
    how='left'
)

# %%
top_fund
# Out:
#    cohort_year  amfi_code  transaction_count  \
# 0         2024     148568                874
# 1         2025     119599                 12
#
#                                          scheme_name
# 0  Mirae Asset Emerging Bluechip Fund - Regular -...
# 1          SBI Small Cap Fund - Direct Plan - Growth

# %%
cohort_analysis = avg_sip.merge(
    total_invested,
    on='cohort_year',
    how='outer'
)

# %%
cohort_analysis = cohort_analysis.merge(
    top_fund[
        [
            'cohort_year',
            'amfi_code',
            'scheme_name',
            'transaction_count'
        ]
    ],
    on='cohort_year',
    how='left'
)

# %%
cohort_analysis
# Out:
#    cohort_year  avg_sip_amount  total_invested  amfi_code  \
# 0         2024    10996.885825      2258062304     148568
# 1         2025    13505.209581        18992635     119599
#
#                                          scheme_name  transaction_count
# 0  Mirae Asset Emerging Bluechip Fund - Regular -...                874
# 1          SBI Small Cap Fund - Direct Plan - Growth                 12

# %%
cohort_analysis['avg_sip_amount'] = (
    cohort_analysis['avg_sip_amount'].round(2)
)

cohort_analysis['total_invested'] = (
    cohort_analysis['total_invested'].round(2)
)

# %%
cohort_analysis.to_csv(
    "C:/MutualFundproject/data/processed/Advanced_Analytics_CSV_file/03_investor_cohort_analysis.csv",
    index=False
)

# %%
## SIP continuity analysis — for investors with 6+ SIP transactions, compute avg gap between dates. Flag investors with gap > 35 days as "at-risk".

# %%
import pandas as pd
import numpy as np

transactions = pd.read_csv(
    "C:/MutualFundProject/data/raw/08_investor_transactions.csv"
)

transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
transactions.columns
# Out:
# Index(['investor_id', 'transaction_date', 'amfi_code', 'transaction_type',
#        'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender',
#        'annual_income_lakh', 'payment_mode', 'kyc_status'],
#       dtype='str')

# %%
transactions['transaction_date'] = pd.to_datetime(
    transactions['transaction_date']
)

# %%
transactions['transaction_date'].min()
transactions['transaction_date'].max()
# Out:
# Timestamp('2025-05-30 00:00:00')

# %%
sip = transactions[
    transactions['transaction_type'].str.upper() == 'SIP'
].copy()

# %%
sip.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 5   INV001497       2024-01-01     101208              SIP        3295
# 6   INV000786       2024-01-01     101208              SIP       15047
#
#             state       city city_tier age_group  gender  annual_income_lakh  \
# 0       Telangana  Hyderabad       T30       56+  Female                77.1
# 2         Haryana  Faridabad       B30     36-45    Male                47.2
# 3     Maharashtra     Mumbai       T30     36-45  Female                54.4
# 5     Maharashtra     Mumbai       T30     36-45    Male                56.8
# 6  Madhya Pradesh     Bhopal       B30     26-35    Male                17.9
#
#   payment_mode kyc_status
# 0          UPI   Verified
# ...

# %%
sip.shape
# Out:
# (19716, 13)

# %%
sip = sip.sort_values(
    ['investor_id', 'transaction_date']
)

# %%
sip_count = (
    sip.groupby('investor_id')
       .size()
       .reset_index(name='sip_count')
)

# %%
sip_count.head()
# Out:
#   investor_id  sip_count
# 0   INV000001          2
# 1   INV000002          3
# 2   INV000003          2
# 3   INV000004          6
# 4   INV000005          3

# %%
eligible_investors = sip_count[
    sip_count['sip_count'] >= 6
]['investor_id']

# %%
sip_eligible = sip[
    sip['investor_id'].isin(eligible_investors)
].copy()

# %%
sip_eligible['investor_id'].nunique()
# Out:
# 1362

# %%
sip_eligible['gap_days'] = (
    sip_eligible
    .groupby('investor_id')['transaction_date']
    .diff()
    .dt.days
)

# %%
sip_eligible[
    ['investor_id', 'transaction_date', 'gap_days']
].head(15)
# Out:
#       investor_id transaction_date  gap_days
# 4773    INV000004       2024-03-16       NaN
# 6418    INV000004       2024-04-11      26.0
# 8271    INV000004       2024-05-09      28.0
# 12003   INV000004       2024-07-07      59.0
# 28749   INV000004       2025-03-29     265.0
# 31897   INV000004       2025-05-17      49.0
# 9329    INV000008       2024-05-27       NaN
# 11113   INV000008       2024-06-23      27.0
# 21549   INV000008       2024-12-05     165.0
# 24389   INV000008       2025-01-18      44.0
# 25907   INV000008       2025-02-11      24.0
# 31674   INV000008       2025-05-14      92.0
# 6467    INV000010       2024-04-11       NaN
# 15384   INV000010       2024-08-28     139.0
# 21247   INV000010       2024-12-01      95.0

# %%
investor_gap = (
    sip_eligible
    .groupby('investor_id')
    .agg(
        sip_count=('transaction_date', 'count'),
        avg_gap_days=('gap_days', 'mean'),
        max_gap_days=('gap_days', 'max')
    )
    .reset_index()
)

# %%
investor_gap.head()
# Out:
#   investor_id  sip_count  avg_gap_days  max_gap_days
# 0   INV000004          6     85.400000         265.0
# 1   INV000008          6     70.400000         165.0
# 2   INV000010          6     64.800000         139.0
# 3   INV000011          7     40.166667         125.0
# 4   INV000012          8     57.000000         132.0

# %%
investor_gap['risk_status'] = np.where(
    investor_gap['avg_gap_days'] > 35,
    'at-risk',
    'active'
)

# %%
max_gap = (
    sip_eligible
    .groupby('investor_id')['gap_days']
    .max()
    .reset_index(name='max_gap_days')
)

# %%
investor_gap['risk_status'] = np.where(
    investor_gap['max_gap_days'] > 35,
    'at-risk',
    'active'
)

# %%
risk_gaps = (
    sip_eligible
    .assign(
        risky_gap=lambda x: x['gap_days'] > 35
    )
    .groupby('investor_id')['risky_gap']
    .sum()
    .reset_index(name='risky_gap_count')
)

# %%
investor_gap = investor_gap.merge(
    risk_gaps,
    on='investor_id',
    how='left'
)

# %%
investor_gap['avg_gap_days'] = (
    investor_gap['avg_gap_days'].round(2)
)

# %%
display(investor_gap)
# Out:
#      investor_id  sip_count  avg_gap_days  max_gap_days risk_status  \
# 0      INV000004          6         85.40         265.0     at-risk
# 1      INV000008          6         70.40         165.0     at-risk
# 2      INV000010          6         64.80         139.0     at-risk
# 3      INV000011          7         40.17         125.0     at-risk
# 4      INV000012          8         57.00         132.0     at-risk
# ...          ...        ...           ...           ...         ...
# 1357   INV004984          7         75.33         177.0     at-risk
# 1358   INV004986          7         81.33         185.0     at-risk
# 1359   INV004992          7         81.50         176.0     at-risk
# 1360   INV004996         10         46.33         104.0     at-risk
# 1361   INV004997          7         71.00         248.0     at-risk
#
#       risky_gap_count
# 0                   3
# 1                   3
# 2                   3
# 3                   3
# 4                   5
# ...

# %%
status_summary = (
    investor_gap['risk_status']
    .value_counts()
    .reset_index()
)

status_summary.columns = [
    'risk_status',
    'investor_count'
]

status_summary
# Out:
#   risk_status  investor_count
# 0     at-risk            1361
# 1      active               1

# %%
status_summary['percentage'] = (
    status_summary['investor_count']
    / status_summary['investor_count'].sum()
    * 100
)

status_summary['percentage'] = (
    status_summary['percentage'].round(2)
)

status_summary
# Out:
#   risk_status  investor_count  percentage
# 0     at-risk            1361       99.93
# 1      active               1        0.07

# %%
investor_gap.sort_values(
    'max_gap_days',
    ascending=False
).head(20)
# Out:
#      investor_id  sip_count  avg_gap_days  max_gap_days risk_status  \
# 256    INV000862          6         91.20         372.0     at-risk
# 26     INV000082          7         83.67         351.0     at-risk
# 798    INV002912          6         97.00         342.0     at-risk
# 536    INV002001          6         84.80         335.0     at-risk
# 956    INV003484          6         73.80         333.0     at-risk
# 882    INV003223          8         67.71         331.0     at-risk
# 578    INV002177          7         73.00         330.0     at-risk
# 311    INV001070          6         97.00         329.0     at-risk
# 1018   INV003686          6         96.60         328.0     at-risk
# 183    INV000608          6        100.20         324.0     at-risk
# 741    INV002736          6         70.60         323.0     at-risk
# 710    INV002628          6         77.00         322.0     at-risk
# 1124   INV004066          7         75.17         319.0     at-risk
# ...

# %%
investor_gap.sort_values(
    'risky_gap_count',
    ascending=False
).head(20)
# Out:
#      investor_id  sip_count  avg_gap_days  max_gap_days risk_status  \
# 117    INV000399         10         49.56          68.0     at-risk
# 817    INV003003          9         58.25         100.0     at-risk
# 1334   INV004889          7         70.67         159.0     at-risk
# 986    INV003598          8         68.00         114.0     at-risk
# 1163   INV004203          8         66.57         113.0     at-risk
# 199    INV000657          8         64.71         106.0     at-risk
# 1115   INV004009          8         62.29          87.0     at-risk
# 194    INV000642          9         53.50         139.0     at-risk
# 1135   INV004116         10         54.89         117.0     at-risk
# 306    INV001060          9         53.38          89.0     at-risk
# 1152   INV004154         12         46.73          90.0     at-risk
# 324    INV001160          8         57.57          99.0     at-risk
# 242    INV000803          7         77.17         147.0     at-risk
# ...

# %%
investor_gap.to_csv(
    "C:/MutualFundProject/data/processed/Advanced_Analytics_CSV_file/04_sip_continuity_analysis.csv",
    index=False
)

# %%
## Simple fund recommender — input: risk appetite (Low / Moderate / High). Output: top 3 funds by Sharpe ratio within matching risk_grade.
## Print recommendation table.

# %%
import pandas as pd
import numpy as np

performance = pd.read_csv(
    "C:/MutualFundProject/data/raw/07_scheme_performance.csv"
)

performance.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
performance.columns
# Out:
# Index(['amfi_code', 'scheme_name', 'fund_house', 'category', 'plan',
#        'return_1yr_pct', 'return_3yr_pct', 'return_5yr_pct',
#        'benchmark_3yr_pct', 'alpha', 'beta', 'sharpe_ratio', 'sortino_ratio',
#        'std_dev_ann_pct', 'max_drawdown_pct', 'aum_crore', 'expense_ratio_pct',
#        'morningstar_rating', 'risk_grade'],
#       dtype='str')

# %%
performance.dtypes
# Out:
# amfi_code               int64
# scheme_name               str
# fund_house                str
# category                  str
# plan                      str
# return_1yr_pct        float64
# return_3yr_pct        float64
# return_5yr_pct        float64
# benchmark_3yr_pct     float64
# alpha                 float64
# beta                  float64
# sharpe_ratio          float64
# sortino_ratio         float64
# std_dev_ann_pct       float64
# max_drawdown_pct      float64
# aum_crore               int64
# expense_ratio_pct     float64
# morningstar_rating      int64
# risk_grade                str
# dtype: object

# %%
performance['risk_grade'].value_counts()
# Out:
# risk_grade
# Moderate           16
# High                8
# Very High           6
# Low                 6
# Moderately High     4
# Name: count, dtype: int64

# %%
performance['risk_grade'].unique()
# Out:
# <StringArray>
# ['Moderate', 'Very High', 'Low', 'High', 'Moderately High']
# Length: 5, dtype: str

# %%
performance['risk_grade'] = (
    performance['risk_grade']
    .str.strip()
    .str.title()
)

# %%
performance['risk_grade'].unique()
# Out:
# <StringArray>
# ['Moderate', 'Very High', 'Low', 'High', 'Moderately High']
# Length: 5, dtype: str

# %%
performance['sharpe_ratio'] = pd.to_numeric(
    performance['sharpe_ratio'],
    errors='coerce'
)

# %%
performance['sharpe_ratio'].isna().sum()
# Out:
# np.int64(0)

# %%
performance = performance.dropna(
    subset=['sharpe_ratio']
).copy()

# %%
performance['amfi_code'].duplicated().sum()
# Out:
# np.int64(0)

# %%
def recommend_funds(risk_appetite):
    
    # Standardize user input
    risk_appetite = risk_appetite.strip().title()
    
    # Validate input
    valid_risks = ['Low', 'Moderate', 'High']
    
    if risk_appetite not in valid_risks:
        print("Invalid risk appetite.")
        print("Choose: Low, Moderate, or High")
        return
    
    # Filter matching risk grade
    filtered = performance[
        performance['risk_grade'] == risk_appetite
    ].copy()
    
    # Sort by Sharpe ratio
    recommendations = (
        filtered
        .sort_values(
            'sharpe_ratio',
            ascending=False
        )
        .head(3)
    )
    
    # Select columns
    recommendations = recommendations[
        [
            'amfi_code',
            'scheme_name',
            'risk_grade',
            'sharpe_ratio'
        ]
    ]
    
    # Add ranking
    recommendations.insert(
        0,
        'rank',
        range(1, len(recommendations) + 1)
    )
    
    print(
        f"\nTop 3 Funds for {risk_appetite} Risk Appetite"
    )
    
    display(recommendations)
    
    return recommendations

# %%
recommend_funds("Low")
# Out:
# Top 3 Funds for Low Risk Appetite
#     rank  amfi_code                               scheme_name risk_grade  \
# 14     1     120507  ICICI Pru Liquid Fund - Regular - Growth        Low
# 23     2     120844      Kotak Liquid Fund - Regular - Growth        Low
# 30     3     101208       ABSL Liquid Fund - Regular - Growth        Low
#
#     sharpe_ratio
# 14          7.68
# 23          6.18
# 30          5.14
#     rank  amfi_code                               scheme_name risk_grade  \
# 14     1     120507  ICICI Pru Liquid Fund - Regular - Growth        Low
# 23     2     120844      Kotak Liquid Fund - Regular - Growth        Low
# 30     3     101208       ABSL Liquid Fund - Regular - Growth        Low
#
#     sharpe_ratio
# 14          7.68
# 23          6.18
# 30          5.14

# %%
recommend_funds("High")
# Out:
# Top 3 Funds for High Risk Appetite
#     rank  amfi_code                                    scheme_name risk_grade  \
# 21     1     120842  Kotak Emerging Equity Fund - Regular - Growth       High
# 12     2     120505       ICICI Pru Midcap Fund - Regular - Growth       High
# 38     3     149323             DSP Midcap Fund - Regular - Growth       High
#
#     sharpe_ratio
# 21          0.96
# 12          0.95
# 38          0.90
#     rank  amfi_code                                    scheme_name risk_grade  \
# 21     1     120842  Kotak Emerging Equity Fund - Regular - Growth       High
# 12     2     120505       ICICI Pru Midcap Fund - Regular - Growth       High
# 38     3     149323             DSP Midcap Fund - Regular - Growth       High
#
#     sharpe_ratio
# 21          0.96
# 12          0.95
# 38          0.90

# %%
risk = input(
    "Enter risk appetite (Low / Moderate / High): "
)

recommend_funds(risk)
# Out:
# Enter risk appetite (Low / Moderate / High):  moderate
# Top 3 Funds for Moderate Risk Appetite
#     rank  amfi_code                                    scheme_name risk_grade  \
# 5      1     100016      HDFC Top 100 Fund - Regular Plan - Growth   Moderate
# 34     2     148567  Mirae Asset Large Cap Fund - Regular - Growth   Moderate
# 11     3     120504      ICICI Pru Bluechip Fund - Direct - Growth   Moderate
#
#     sharpe_ratio
# 5           1.06
# 34          1.06
# 11          1.03
#     rank  amfi_code                                    scheme_name risk_grade  \
# 5      1     100016      HDFC Top 100 Fund - Regular Plan - Growth   Moderate
# 34     2     148567  Mirae Asset Large Cap Fund - Regular - Growth   Moderate
# 11     3     120504      ICICI Pru Bluechip Fund - Direct - Growth   Moderate
#
#     sharpe_ratio
# 5           1.06
# 34          1.06
# 11          1.03

# %%
def recommend_funds(risk_appetite):

    risk_appetite = risk_appetite.strip().title()

    valid_risks = ['Low', 'Moderate', 'High']

    if risk_appetite not in valid_risks:
        print("Invalid risk appetite.")
        print("Choose: Low, Moderate, or High.")
        return

    filtered = performance[
        performance['risk_grade'] == risk_appetite
    ].copy()

    if filtered.empty:
        print(
            f"No funds found for {risk_appetite} risk grade."
        )
        return

    recommendations = (
        filtered
        .sort_values(
            'sharpe_ratio',
            ascending=False
        )
        .head(3)
    )

    print(recommendations)

    return recommendations

# %%
recommendations = recommend_funds("Moderate")

if recommendations is not None:
    recommendations.to_csv(
        "C:/MutualFundProject/data/processed/Advanced_Analytics_CSV_file/05_fund_recommendations_moderate.csv",
        index=False
    )
# Out:
#     amfi_code                                    scheme_name  \
# 5      100016      HDFC Top 100 Fund - Regular Plan - Growth
# 34     148567  Mirae Asset Large Cap Fund - Regular - Growth
# 11     120504      ICICI Pru Bluechip Fund - Direct - Growth
#
#              fund_house   category     plan  return_1yr_pct  return_3yr_pct  \
# 5      HDFC Mutual Fund  Large Cap  Regular           10.94           14.84
# 34       Mirae Asset MF  Large Cap  Regular           15.12           14.81
# 11  ICICI Prudential MF  Large Cap   Direct           14.12           14.41
#
#     return_5yr_pct  benchmark_3yr_pct  alpha  beta  sharpe_ratio  \
# 5            11.32              14.06   0.78  0.97          1.06
# 34           12.68              13.19   1.62  0.96          1.06
# 11           13.02              13.53   0.88  1.03          1.03
#
#     sortino_ratio  std_dev_ann_pct  max_drawdown_pct  aum_crore  \
# 5            1.70             14.0            -17.41       6434
# ...

# %%
## Sector HHI concentration — Herfindahl-Hirschman Index = Σ(weight_i²) per fund. High HHI = concentrated portfolio. Compare across all equity funds.

# %%
import pandas as pd
import numpy as np

holdings = pd.read_csv(
    "C:/MutualFundProject/data/processed/cleaned_dataset/09_holdings_portfolio.csv"
)

holdings.head()
# Out:
#    amfi_code stock_symbol                stock_name       sector  weight  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities   13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking   11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified    9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma    4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints   10.25
#
#    market_value_cr  current_price_inr portfolio_date  \
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31
#
#                                  scheme_name        fund_type
# 0  SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1  SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# ...

# %%
holdings.columns
# Out:
# Index(['amfi_code', 'stock_symbol', 'stock_name', 'sector', 'weight',
#        'market_value_cr', 'current_price_inr', 'portfolio_date', 'scheme_name',
#        'fund_type'],
#       dtype='str')

# %%
holdings.shape
# Out:
# (322, 10)

# %%
holdings.dtypes
# Out:
# amfi_code              int64
# stock_symbol             str
# stock_name               str
# sector                   str
# weight               float64
# market_value_cr      float64
# current_price_inr    float64
# portfolio_date           str
# scheme_name              str
# fund_type                str
# dtype: object

# %%
holdings['sector'].nunique()
# Out:
# 14

# %%
holdings['sector'].unique()
# Out:
# <StringArray>
# [     'Utilities',        'Banking',    'Diversified',         'Pharma',
#          'Paints',        'Telecom',             'IT',     'Automobile',
#            'NBFC',         'Cement',         'Energy', 'Consumer Goods',
#            'FMCG', 'Infrastructure']
# Length: 14, dtype: str

# %%
holdings['weight'] = pd.to_numeric(
    holdings['weight'],
    errors='coerce'
)

# %%
holdings['weight'] = pd.to_numeric(
    holdings['weight'],
    errors='coerce'
)

# %%
holdings = holdings.dropna(
    subset=['weight']
).copy()

# %%
holdings['weight'].describe()
# Out:
# count    322.000000
# mean      10.558975
# std        6.060137
# min        0.990000
# 25%        6.015000
# 50%        9.395000
# 75%       13.917500
# max       38.180000
# Name: weight, dtype: float64

# %%
holdings['weight_decimal'] = holdings['weight'] / 100

# %%
holdings['weight_decimal'] = holdings['weight']

# %%
sector_weights = (
    holdings
    .groupby(
        ['amfi_code', 'sector'],
        as_index=False
    )['weight_decimal']
    .sum()
)

# %%
sector_weights.head(20)
# Out:
#     amfi_code          sector  weight_decimal
# 0      100016      Automobile           14.84
# 1      100016         Banking            3.39
# 2      100016          Energy            6.09
# 3      100016            FMCG           11.68
# 4      100016              IT           25.90
# 5      100016            NBFC            7.01
# 6      100016          Pharma           25.48
# 7      100016       Utilities            5.61
# 8      100033      Automobile           26.07
# 9      100033         Banking           35.97
# 10     100033              IT            4.66
# 11     100033  Infrastructure            7.47
# 12     100033            NBFC            9.86
# 13     100033         Telecom            7.38
# 14     100033       Utilities            8.59
# 15     101206      Automobile           25.01
# 16     101206         Banking           25.09
# 17     101206          Energy           10.11
# 18     101206  Infrastructure           14.91
# ...

# %%
sector_weights['weight_squared'] = (
    sector_weights['weight_decimal'] ** 2
)

# %%
sector_weights.head()
# Out:
#    amfi_code      sector  weight_decimal  weight_squared
# 0     100016  Automobile           14.84        220.2256
# 1     100016     Banking            3.39         11.4921
# 2     100016      Energy            6.09         37.0881
# 3     100016        FMCG           11.68        136.4224
# 4     100016          IT           25.90        670.8100

# %%
hhi = (
    sector_weights
    .groupby('amfi_code')['weight_squared']
    .sum()
    .reset_index()
)

# %%
hhi = hhi.rename(
    columns={
        'weight_squared': 'sector_hhi'
    }
)

# %%
hhi.head()
# Out:
#    amfi_code  sector_hhi
# 0     100016   1805.8808
# 1     100033   2276.4744
# 2     101206   1800.4225
# 3     101207   2227.2651
# 4     102885   1807.1202

# %%
fund_master = pd.read_csv(
    "C:/MutualFundProject/data/raw/01_fund_master.csv"
)

# %%
hhi = hhi.merge(
    fund_master[
        ['amfi_code', 'scheme_name', 'category']
    ],
    on='amfi_code',
    how='left'
)

# %%
hhi.head()
# Out:
#    amfi_code  sector_hhi                                        scheme_name  \
# 0     100016   1805.8808          HDFC Top 100 Fund - Regular Plan - Growth
# 1     100033   2276.4744  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 2     101206   1800.4225      ABSL Frontline Equity Fund - Regular - Growth
# 3     101207   2227.2651             ABSL Small Cap Fund - Regular - Growth
# 4     102885   1807.1202         UTI Nifty 50 Index Fund - Regular - Growth
#
#   category
# 0   Equity
# 1   Equity
# 2   Equity
# 3   Equity
# 4   Equity

# %%
equity_categories = [
    'Large Cap',
    'Mid Cap',
    'Small Cap',
    'Large & Mid Cap',
    'Flexi Cap',
    'Multi Cap',
    'ELSS',
    'Focused'
]

# %%
equity_hhi = hhi[
    hhi['category'].isin(equity_categories)
].copy()

# %%
equity_hhi['amfi_code'].nunique()
# Out:
# 0

# %%
equity_hhi = equity_hhi.sort_values(
    'sector_hhi',
    ascending=False
)

# %%
equity_hhi[
    [
        'scheme_name',
        'category',
        'sector_hhi'
    ]
]
# Out:
# Empty DataFrame
# Columns: [scheme_name, category, sector_hhi]
# Index: []

# %%
def classify_hhi(hhi):
    
    if hhi < 0.15:
        return 'Low Concentration'
    elif hhi < 0.25:
        return 'Moderate Concentration'
    else:
        return 'High Concentration'

# %%
equity_hhi['concentration_level'] = (
    equity_hhi['sector_hhi']
    .apply(classify_hhi)
)

# %%
equity_hhi.head(10)
# Out:
# Empty DataFrame
# Columns: [amfi_code, sector_hhi, scheme_name, category, concentration_level]
# Index: []

# %%
equity_hhi.head(10)
# Out:
# Empty DataFrame
# Columns: [amfi_code, sector_hhi, scheme_name, category, concentration_level]
# Index: []

# %%
equity_hhi.sort_values(
    'sector_hhi'
).head(10)
# Out:
# Empty DataFrame
# Columns: [amfi_code, sector_hhi, scheme_name, category, concentration_level]
# Index: []

# %%
category_hhi = (
    equity_hhi
    .groupby('category')['sector_hhi']
    .agg(
        average_hhi='mean',
        median_hhi='median',
        minimum_hhi='min',
        maximum_hhi='max',
        fund_count='count'
    )
    .reset_index()
)

# %%
category_hhi.sort_values(
    'average_hhi',
    ascending=False
)
# Out:
# Empty DataFrame
# Columns: [category, average_hhi, median_hhi, minimum_hhi, maximum_hhi, fund_count]
# Index: []

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plot_data = equity_hhi.sort_values(
    'sector_hhi',
    ascending=True
)

plt.figure(figsize=(12, 10))

sns.barplot(
    data=plot_data,
    x='sector_hhi',
    y='scheme_name'
)

plt.axvline(
    0.15,
    linestyle='--',
    linewidth=1,
    label='0.15 reference'
)

plt.axvline(
    0.25,
    linestyle='--',
    linewidth=1,
    label='0.25 reference'
)

plt.title(
    'Sector HHI Concentration Across Equity Funds'
)

plt.xlabel('Sector HHI')
plt.ylabel('Fund')
plt.legend()

plt.tight_layout()

plt.show()

# %%
plt.savefig(
    "C:/MutualFundProject/data/processed/Advanced_Analytics_CSV_file/reports/sector_hhi_equity_funds.png",
    dpi=300,
    bbox_inches='tight'
)
