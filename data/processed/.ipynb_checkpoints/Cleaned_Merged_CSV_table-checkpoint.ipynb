# %%
# Create a Table For Nav_History

# %%
import pandas as pd
import plotly.express as px

nav = pd.read_csv("C:/MutualFundProject/data/raw/02_nav_history.csv")

nav.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
fund_master = pd.read_csv("C:/MutualFundProject/data/raw/01_fund_master.csv")

print(fund_master.columns)
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='str')

# %%
nav = nav.merge(
    fund_master[["amfi_code", "scheme_name"]],
    on="amfi_code",
    how="left"
)

# %%
print(nav["scheme_name"].isna().sum())
# Out:
# 0

# %%
print(nav.columns)
# Out:
# Index(['amfi_code', 'date', 'nav', 'scheme_name'], dtype='str')

# %%
nav.to_csv(
    "c:/MutualFundProject/data/processed/cleaned_dataset/02_nav_history.csv",
    index=False
)

# %%
## Create Table For Aum_History

# %%
aum = pd.read_csv("c:/MutualFundProject/data/raw/03_fund_aum.csv")

aum.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
aum.rename(
    columns={"aum_crore": "aum"},
    inplace=True
)

# %%
aum.shape
# Out:
# (90, 5)

# %%
aum.dtypes
# Out:
# date                  str
# fund_house            str
# aum_lakh_crore    float64
# aum                 int64
# num_schemes         int64
# dtype: object

# %%
aum["date"] = pd.to_datetime(aum["date"])

# %%
aum["year"] = (aum["date"].dt.year)

# %%
aum_history = (
    aum
    .sort_values(["fund_house", "date"])
    .groupby(["fund_house", "year"])
    .tail(1)
)

# %%
aum_history = aum_history[
    ["fund_house", "year", "aum"]
]

# %%
aum_history.head()
# Out:
#                   fund_house  year     aum
# 15  Aditya Birla Sun Life MF  2022  285000
# 35  Aditya Birla Sun Life MF  2023  308000
# 65  Aditya Birla Sun Life MF  2024  384000
# 85  Aditya Birla Sun Life MF  2025  460000
# 16          Axis Mutual Fund  2022  240000

# %%
import os

os.makedirs("c:/MutualFundProject/data/processed/cleaned_dataset", exist_ok=True)

# %%
aum_history.to_csv(
    "c:/MutualFundProject/data/processed/cleaned_dataset/03_aum_history.csv",
    index=False
)

# %%
# Investor_demographics Table

# %%
import pandas as pd

df = pd.read_csv("C:/MutualFundProject/data/raw/08_investor_transactions.csv")

print(df.shape)
print(df.head())
print(df.columns)
print(df.dtypes)
# Out:
# (32778, 13)
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# ...

# %%
sip_df = df.rename(
    columns={'amount_inr': 'sip_amount'}
)

# %%
sip_amount_table = sip_df[
    ['investor_id', 'age_group', 'gender', 'sip_amount']
].copy()
print(sip_amount_table.head())
# Out:
#   investor_id age_group  gender  sip_amount
# 0   INV003054       56+  Female        1834
# 1   INV002952     18-25    Male      392882
# 2   INV003420     36-45    Male         912
# 3   INV003436     36-45  Female        1102
# 4   INV004691     26-35    Male        8682

# %%
print(sip_df[['investor_id', 'age_group', 'gender', 'sip_amount']].isnull().sum())
# Out:
# investor_id    0
# age_group      0
# gender         0
# sip_amount     0
# dtype: int64

# %%
print(df['age_group'].value_counts().sort_index())
# Out:
# age_group
# 18-25     4916
# 26-35    13463
# 36-45     8146
# 46-55     3779
# 56+       2474
# Name: count, dtype: int64

# %%
age_counts = df['age_group'].value_counts().sort_index()

print(age_counts)
# Out:
# age_group
# 18-25     4916
# 26-35    13463
# 36-45     8146
# 46-55     3779
# 56+       2474
# Name: count, dtype: int64

# %%
investor_df = sip_df.drop(columns=["transaction_date","amfi_code","state","city","city_tier","annual_income_lakh","payment_mode","kyc_status"])
print(investor_df.head())
# Out:
#   investor_id transaction_type  sip_amount age_group  gender
# 0   INV003054              SIP        1834       56+  Female
# 1   INV002952       Redemption      392882     18-25    Male
# 2   INV003420              SIP         912     36-45    Male
# 3   INV003436              SIP        1102     36-45  Female
# 4   INV004691          Lumpsum        8682     26-35    Male

# %%
investor_df.to_csv(
    "C:/MutualFundProject/data/processed/cleaned_dataset/08_investor_transactions.csv",
     index=False
)
print("file saved sucessfully!")
# Out:
# file saved sucessfully!

# %%
investor_df
# Out:
#       investor_id transaction_type  sip_amount age_group  gender
# 0       INV003054              SIP        1834       56+  Female
# 1       INV002952       Redemption      392882     18-25    Male
# 2       INV003420              SIP         912     36-45    Male
# 3       INV003436              SIP        1102     36-45  Female
# 4       INV004691          Lumpsum        8682     26-35    Male
# ...           ...              ...         ...       ...     ...
# 32773   INV003340          Lumpsum      168029     26-35    Male
# 32774   INV001838              SIP        2175     46-55    Male
# 32775   INV000074              SIP       25998     26-35  Female
# 32776   INV002929              SIP         459     26-35    Male
# 32777   INV001852       Redemption      226721     26-35    Male
#
# [32778 rows x 5 columns]

# %%
df
# Out:
#       investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0       INV003054       2024-01-01     119092              SIP        1834
# 1       INV002952       2024-01-01     148567       Redemption      392882
# 2       INV003420       2024-01-01     118636              SIP         912
# 3       INV003436       2024-01-01     118634              SIP        1102
# 4       INV004691       2024-01-01     119094          Lumpsum        8682
# ...           ...              ...        ...              ...         ...
# 32773   INV003340       2025-05-30     101207          Lumpsum      168029
# 32774   INV001838       2025-05-30     119093              SIP        2175
# 32775   INV000074       2025-05-30     120504              SIP       25998
# 32776   INV002929       2025-05-30     148568              SIP         459
# 32777   INV001852       2025-05-30     118633       Redemption      226721
#
#                 state       city city_tier age_group  gender  \
# ...

# %%
investor_df = investor_df.merge(df[['investor_id','state','city_tier']], on='investor_id')

# %%
print(investor_df)
# Out:
#        investor_id transaction_type  sip_amount age_group  gender      state  \
# 0        INV003054              SIP        1834       56+  Female  Telangana
# 1        INV003054              SIP        1834       56+  Female  Telangana
# 2        INV003054              SIP        1834       56+  Female  Telangana
# 3        INV003054              SIP        1834       56+  Female  Telangana
# 4        INV003054              SIP        1834       56+  Female  Telangana
# ...            ...              ...         ...       ...     ...        ...
# 274427   INV001852       Redemption      226721     26-35    Male  Telangana
# 274428   INV001852       Redemption      226721     26-35    Male  Telangana
# 274429   INV001852       Redemption      226721     26-35    Male  Telangana
# 274430   INV001852       Redemption      226721     26-35    Male  Telangana
# 274431   INV001852       Redemption      226721     26-35    Male  Telangana
#
#        city_tier
# 0            T30
# ...

# %%
investor_df.to_csv(
    "C:/MutualFundProject/data/processed/cleaned_dataset/08_investor_demographics.csv",
     index=False
)
print("file saved sucessfully!")
# Out:
# file saved sucessfully!

# %%
# Portfolio_Holdings_table

# %%
import pandas as pd

holdings = pd.read_csv("C:/MutualFundProject/data/raw/09_portfolio_holdings.csv")
fund_master = pd.read_csv("C:/MutualFundProject/data/raw/01_fund_master.csv")

print(holdings.columns)
print(fund_master.columns)
# Out:
# Index(['amfi_code', 'stock_symbol', 'stock_name', 'sector', 'weight_pct',
#        'market_value_cr', 'current_price_inr', 'portfolio_date'],
#       dtype='str')
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='str')

# %%
holdings = holdings.merge(
    fund_master[
        ['amfi_code', 'scheme_name', 'fund_house']
    ],
    on='amfi_code',
    how='left'
)

# %%
print(holdings.head())
# Out:
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date  \
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31
#
#                                  scheme_name       fund_house
# 0  SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# ...

# %%
holdings_df = holdings.rename(columns={"fund_house":"fund_type","weight_pct":"weight"})

# %%
holdings_df.to_csv(
    "C:/MutualFundProject/data/processed/cleaned_dataset/09_holdings_portfolio.csv",
     index=False
)
print("file saved sucessfully!")
# Out:
# file saved sucessfully!

# %%
# NIFTY 50 Table

# %%
import pandas as pd

df = pd.read_csv("C:/MutualFundProject/data/raw/10_benchmark_indices.csv")

# Filter only NIFTY50
nifty50 = df[
    df["index_name"].astype(str).str.strip().str.upper() == "NIFTY50"
].copy()

# Print NIFTY50 data
print(nifty50)
# Out:
#             date index_name  close_value
# 0     2022-01-03    NIFTY50     17492.79
# 1     2022-01-04    NIFTY50     17689.64
# 2     2022-01-05    NIFTY50     17835.05
# 3     2022-01-06    NIFTY50     17878.51
# 4     2022-01-07    NIFTY50     17759.15
# ...          ...        ...          ...
# 1145  2026-05-25    NIFTY50     18186.57
# 1146  2026-05-26    NIFTY50     18418.36
# 1147  2026-05-27    NIFTY50     18523.57
# 1148  2026-05-28    NIFTY50     18421.08
# 1149  2026-05-29    NIFTY50     18517.65
#
# [1150 rows x 3 columns]

# %%
nifty50['daily_return'] = (
    nifty50['close_value'] / nifty50['close_value'].shift(1)
) - 1

# %%
nifty50['daily_return'] = nifty50['close_value'].pct_change()

# %%
print(nifty50.head())
# Out:
#          date index_name  close_value  daily_return
# 0  2022-01-03    NIFTY50     17492.79           NaN
# 1  2022-01-04    NIFTY50     17689.64      0.011253
# 2  2022-01-05    NIFTY50     17835.05      0.008220
# 3  2022-01-06    NIFTY50     17878.51      0.002437
# 4  2022-01-07    NIFTY50     17759.15     -0.006676

# %%
nifty50_returns = nifty50[['date', 'close_value', 'daily_return']].copy()

nifty50_returns = nifty50_returns.rename(
    columns={'daily_return': 'nifty50_return'}
)

# %%
print(nifty50_returns.head())
# Out:
#          date  close_value  nifty50_return
# 0  2022-01-03     17492.79             NaN
# 1  2022-01-04     17689.64        0.011253
# 2  2022-01-05     17835.05        0.008220
# 3  2022-01-06     17878.51        0.002437
# 4  2022-01-07     17759.15       -0.006676

# %%
# Save to CSV
nifty50_returns.to_csv("C:/MutualFundProject/data/raw/nifty50.csv", index=False)

# %%
## Nifty 100 Table

# %%
import pandas as pd

df = pd.read_csv("C:/MutualFundProject/data/raw/10_benchmark_indices.csv")

# Filter only NIFTY50
nifty100 = df[
    df["index_name"].astype(str).str.strip().str.upper() == "NIFTY100"
].copy()

# Print NIFTY50 data
print(nifty100)

# Save to CSV
## nifty50.to_csv("nifty50_only.csv", index=False)
# Out:
#             date index_name  close_value
# 1150  2022-01-03   NIFTY100     17778.24
# 1151  2022-01-04   NIFTY100     17537.52
# 1152  2022-01-05   NIFTY100     17607.73
# 1153  2022-01-06   NIFTY100     17556.05
# 1154  2022-01-07   NIFTY100     17664.02
# ...          ...        ...          ...
# 2295  2026-05-25   NIFTY100     19245.64
# 2296  2026-05-26   NIFTY100     19228.08
# 2297  2026-05-27   NIFTY100     19489.24
# 2298  2026-05-28   NIFTY100     19677.97
# 2299  2026-05-29   NIFTY100     19696.29
#
# [1150 rows x 3 columns]

# %%
nifty100['daily_return'] = (
    nifty100['close_value'] / nifty50['close_value'].shift(1)
) - 1

# %%
nifty100['daily_return'] = nifty100['close_value'].pct_change()

# %%
print(nifty100.head())
# Out:
#             date index_name  close_value  daily_return
# 1150  2022-01-03   NIFTY100     17778.24           NaN
# 1151  2022-01-04   NIFTY100     17537.52     -0.013540
# 1152  2022-01-05   NIFTY100     17607.73      0.004003
# 1153  2022-01-06   NIFTY100     17556.05     -0.002935
# 1154  2022-01-07   NIFTY100     17664.02      0.006150

# %%
nifty100_returns = nifty100[['date', 'close_value', 'daily_return']].copy()

nifty100_returns = nifty100_returns.rename(
    columns={'daily_return': 'nifty50_return'}
)

# %%
# Save to CSV
nifty100_returns.to_csv("C:/MutualFundProject/data/raw/nifty100.csv", index=False)
